# %% [markdown]
# # Assignment 5
#
# In this assignment, we'll finally work with some nonconjugate models. I will also introduce you to reparameterization techniques.
#
# ## Instructions
#
# Please complete this Jupyter notebook and **don't** convert it to a `.py` file. Upload this notebook, along with any `.stan` files and any data sets as a `zip` file to Gradescope.
#
# Your work will be manually graded by our TA. There is no autograder for this assignment. For free response questions, feel free to add a markdown cell and type in there. Try to keep the preexisting structure as much as possible, and to be organized and label which cells correspond with which questions.

# %% [markdown]
# ### Problem 1: Poisson Data
#
# In the last assignment, we modeled a vector of counts $y = (y_1, \ldots, y_n)$ using a multinomial distribution.
#
# Unlike last time, all of these counts will now assumed to be independent. Further, we can't reasonably put a bound on what each count could be. So, in this problem, we'll use a **Poisson likelihood**:
#
# $$
# L(y \mid \theta) = \prod_{i=1}^n L(y_i \mid \theta) \propto \prod_{i=1}^n e^{-\theta}\theta^{y_i} = e^{-n\theta}\theta^{\sum_i y_i}
# $$
#
# With this likelihood, $\theta > 0$ is interpreted as a rate or average.
#
# The data can be found in `Road_Casualties_in_Great_Britain_1969___84_434_19.csv` Use the `DriversKilled` column only.

# %% [markdown]
# 1.
#
# Name a conjugate prior for this likelihood! Write your single-word answer in Gradescope.

# %% [markdown]
# -------
#
# ## Gamma Distribution
#
# -------

# %% [markdown]
# 2.
#
# Suppose that the previous answer does not suite your needs, and that you want to use a lognormal prior! Pick a specific prior distribution (i.e. specify the hyperparameters), and describe a rationale as to why you chose them.

# %% [markdown]
# -------
#
# Given that $\theta \propto LogNormal(\mu, \sigma)$
#
# $$\mu=1$$
#
# $$\sigma=0.5$$
#
# I will use a $\mu = 1$ and a $\sigma = 0.5$. These hyperparameter choices make sense in a log normal context because $\mu=1$ implies that the median (a better value than the mean for finding the most common value because of the lognormal skew) is $e^{1}$ which is standard for log normal. The $\sigma = 0.5$ is my choice simply to allow a reasonable amount of variance while still holding generally to a standard log normal distribution shape.
#
# -------

# %% [markdown]
# 3.
#
# Use `stan` to estimate your model for the "DriversKilled" column. Please be sure to
#
#  - report an $\hat{R}$ diagnostic and comment on whether it is close to $1$
#  - display trace plots of your samples obtained and comment on whether they look like "fuzzy caterpillars."
#
# Then, after checking diagnostics...
#
#  - display a histogram of the posterior for $\theta$
#  - report estimates of the mean, 5th and 95th percentiles of this posterior
#  - comment on whether your posterior mean is close to the frequentist estimator of $\theta$ (which is the sample mean of your data)

# %%
import pandas as pd
from cmdstanpy import CmdStanModel
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("Road_Casualties_in_Great_Britain_1969___84_434_19.csv")
data = data['DriversKilled'].dropna().values

stan_data = {
    "y": data,
    "n_trials": len(data)
}

posterior = CmdStanModel(stan_file="./poisson.stan")
# Out:
# 16:10:45 - cmdstanpy - INFO - compiling stan file /bml24/assignment5/poisson.stan to exe file /bml24/assignment5/poisson
# 16:11:07 - cmdstanpy - INFO - compiled model executable: /bml24/assignment5/poisson

# %%
fit = posterior.sample(stan_data)
# Out:
# 16:14:10 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 16:14:10 - cmdstanpy - INFO - CmdStan done processing.

# %%
# Looks like a fuzzy caterpillar! R_hat right at 1!
fit.draws_pd()['theta'].plot()
details.loc['theta', ['R_hat']]
# Out:
# R_hat    1.00125
# Name: theta, dtype: float64

# %%
fit.draws_pd()['theta'].hist()
details = fit.summary()
details.loc['theta', ['Mean', '5%', '95%']]
# Out:
# Mean    122.707
# 5%      121.424
# 95%     123.979
# Name: theta, dtype: float64

# %%
#Frequentist mean very close to parameter mean, 122.8(sample_data) vs 122.7(posterior)!
np.mean(data)
# Out:
# 122.80208333333333

# %% [markdown]
# 4.
#
# Now use `stan` to estimate a slightly reparameterized model. Suppose you want to use a normal prior on an unconstrained parameter. Notice that if something is positive, then the (natural) log of it is unconstrained. Similarly, if something is unconstrained, the exponential of it is positive.
#
# Therefore, use the following model
#
#
# $$
# \theta \sim \text{Normal}(a,b)
# $$
# and
# $$
# y_i \mid \theta \sim \text{Poisson}(e^{\theta})
# $$
#
#
# Use `stan` to estimate your model for the "DriversKilled" column. Please be sure to
#
#  - report an $\hat{R}$ diagnostic and comment on whether it is close to $1$
#  - display trace plots of your samples obtained and comment on whether they look like "fuzzy caterpillars."
#
# Then, after checking diagnostics...
#
#  - display a histogram of the posterior for $\theta$
#  - display a histogram of the posterior for the transformed parameter, too.
#  - report estimates of the mean, 5th and 95th percentiles of the posterior of the unconstrained $\theta$
#  - comment on whether your posterior mean is close to the frequentist estimator (which is the sample mean of your data)

# %%
posterior = CmdStanModel(stan_file="./reparameterized.stan")
# Out:
# 16:27:27 - cmdstanpy - INFO - compiling stan file /bml24/assignment5/reparameterized.stan to exe file /bml24/assignment5/reparameterized
# 16:27:52 - cmdstanpy - INFO - compiled model executable: /bml24/assignment5/reparameterized

# %%
fit = posterior.sample(stan_data)
# Out:
# 16:27:54 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 16:27:54 - cmdstanpy - INFO - CmdStan done processing.
# 16:27:54 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: poisson_lpmf: Rate parameter is -1.70352, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# 	Exception: poisson_lpmf: Rate parameter is -0.967951, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# 	Exception: poisson_lpmf: Rate parameter is -36.7827, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# Exception: poisson_lpmf: Rate parameter is -158.44, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# 	Exception: poisson_lpmf: Rate parameter is -47.4582, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# Exception: poisson_lpmf: Rate parameter is -0.85551, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# 	Exception: poisson_lpmf: Rate parameter is -1.93457, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# 	Exception: poisson_lpmf: Rate parameter is -0.126518, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# Exception: poisson_lpmf: Rate parameter is -6.24034, but must be nonnegative! (in 'reparameterized.stan', line 17, column 2 to column 21)
# Consider re-running with show_console=True if the above output is unclear!

# %%
# Looks like a fuzzy caterpillar! R_hat right at 1!
fit.draws_pd()['theta'].plot()
details.loc['theta', ['R_hat']]
# Out:
# R_hat    1.00125
# Name: theta, dtype: float64

# %%
fit.draws_pd()['theta'].hist()
details = fit.summary()
details.loc['theta', ['Mean', '5%', '95%']]
# Out:
# Mean    122.809
# 5%      121.511
# 95%     124.089
# Name: theta, dtype: float64

# %%
#Frequentist mean very close to parameter mean, 122.8(sample_data) vs 122.7(posterior)!
np.mean(data)
# Out:
# 122.80208333333333

# %% [markdown]
# ### Problem 2: Binomial Data (again!)
#
# Suppose that you have $m > 1$ count data points $y_1, \ldots, y_m$, each having a $\text{Binomial}(n,\eta)$ distribution. Assume further that they're all independent.
#
# Here $n$ is the maximum for each data point. $m$ is the number of data points.
#
# In our second homework we used the beta prior for the parameter that was bounded between $0$ and $1$.
#
# Now, you must use a normal prior for an unconstrained parameter.
#
# If $0 < \eta < 1$, then the *logit* transformation is a way to make $-\infty < \theta < \infty$ (unconstrained). Alternatively, if you have $\eta$ that's unconstrained, then the `inv_logit` will squash the value to lie between $0$ and $1$.
#
#
# `stan` conveniently has a `logit()` and an `inv_logit()` function already made for you.

# %% [markdown]
# Use `stan` to estimate your model on any fictitious data you would like. Be sure to
#
#  - report an $\hat{R}$ diagnostic and comment on whether it is close to $1$
#  - display trace plots of your samples obtained and comment on whether they look like "fuzzy caterpillars."
#
# Then, after checking diagnostics...
#
#  - display a histogram of the posterior for $\theta$
#  - display a histogram of the posterior for the transformed parameter, too.
#  - report estimates of the mean, 5th and 95th percentiles of the posterior of the unconstrained $\theta$
#  - comment on whether your posterior mean is close to the frequentist estimator (which is the sample mean of your data, again).

# %%
m=1000

synthetic_data = np.random.normal(0, 1, m)

true_eta = 1 / (1 + np.exp(-synthetic_data))

n = np.random.randint(5, 20, size=m)

# Generate binomial data using true_eta
y = np.random.binomial(n, true_eta)

# %%
stan_data = {
    'm': m,
    'n': n,
    'y': y
}

posterior = CmdStanModel(stan_file="./binomial.stan")
# Out:
# 16:56:26 - cmdstanpy - INFO - compiling stan file /bml24/assignment5/binomial.stan to exe file /bml24/assignment5/binomial
# 16:56:45 - cmdstanpy - INFO - compiled model executable: /bml24/assignment5/binomial

# %%
fit = posterior.sample(stan_data)
# Out:
# 16:56:45 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 16:56:46 - cmdstanpy - INFO - CmdStan done processing.

# %%
# Looks like a fuzzy caterpillar! R_hat right at 1!
fit.draws_pd()['theta'].plot()
details.loc['theta', ['R_hat']]
# Out:
# R_hat    1.00063
# Name: theta, dtype: float64

# %%
fit.draws_pd()['theta'].hist()
details = fit.summary()
details.loc['theta', ['Mean', '5%', '95%']]
# Out:
# Mean    0.505738
# 5%      0.498242
# 95%     0.513308
# Name: theta, dtype: float64

# %%
#Frequentist mean nearly identical to posterior mean 0.505 = 0.505
np.mean(y / n)
# Out:
# 0.5055826536595499
